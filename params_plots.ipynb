# %%
from lab.sinus_vs_square_hard import models
model = models.quantum_model_config_dudas
model.summary()
# Out:
# {
#     "name": "Quantum Model",
#     "id": {},
#     "loss": "CrossEntropy()",
#     "metric": "Accuracy()",
#     "batch_size": 80,
#     "nb_epochs": 1,
#     "neural_network_config": {
#         "name": "Linear",
#         "layers_config": [
#             {
#                 "input_dim": 140,
#                 "output_dim": 2,
#                 "activation": "Softmax()"
#             }
#         ]
#     },
#     "neural_network_optimizer_config": {
#         "learning_rate": 0.02,
#         "beta1": 0.9,
#         "beta2": 0.99,
#         "epsilon": 1e-08
#     },
#     "quantum_network_config": {
#         "name": "Q_Network",
#         "quantum_constants": {
#             "DIM_A": 15,
#             "DIM_B": 15,
#             "OMEGA_A": 10000.0,
#             "OMEGA_B": 9000.0,
#             "KAPPA_A": 17,
#             "KAPPA_B": 21,
#             "K_AA": 0.1,
#             "K_BB": 0.1,
#             "K_AB": 0.05,
#             "EPSILON_A": 130,
# ...
