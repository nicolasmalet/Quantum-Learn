# %%
import pickle

with open('experiments/dudas/models/weights.pkl', 'rb') as f:
    data = pickle.load(f)

data
# Out:
# {'Ws': [array([[-0.61343404,  0.14358482,  0.75444593, ...,  0.52042043,
#            0.35785873, -0.54086551],
#          [ 0.57761582,  0.06363044, -0.506525  , ..., -0.57245665,
#           -0.23904733,  0.38439603],
#          [-0.4075415 , -0.01132756, -0.00532447, ...,  0.1955055 ,
#           -0.18046546, -0.04504794],
#          ...,
#          [ 0.05085976,  0.03917114, -0.02952417, ...,  0.09664716,
#           -0.05085229,  0.00821527],
#          [ 0.00941708,  0.07607107, -0.07715513, ...,  0.02959978,
#            0.26041472,  0.12253309],
#          [-0.29009872,  0.11782335, -0.3056082 , ...,  0.00261012,
#            0.17660788,  0.08264881]], shape=(40, 40)),
#   array([[ 0.07118344, -0.27551971],
#          [-0.0898918 ,  0.23813869],
#          [ 0.11641733, -0.17763314],
#          [ 0.43191856, -0.38951904],
#          [-0.32124335, -0.1627493 ],
#          [-0.24907549, -0.39184248],
#          [ 0.30255887, -0.12035721],
#          [ 0.14036892, -0.21012943],
# ...
