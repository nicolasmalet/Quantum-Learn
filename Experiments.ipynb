# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import sys
import os

PROJECT_PATH = '/content/drive/MyDrive/PycharmProjects/Quantum-Learn'
sys.path.append(PROJECT_PATH)

os.chdir(PROJECT_PATH)

# %%
# !pip install -r requirements.txt
# !pip install --upgrade --force-reinstall "jax[cuda12_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !pip install --upgrade jax-cuda12-plugin jax-cuda12-pjrt

# !sudo apt-get update
# !sudo apt-get install -y texlive-latex-extra texlive-fonts-recommended texlive-fonts-extra dvipng cm-super

# %%
from lab.sinus_vs_square_hard import experiments
from zeroth.experiment import Experiment, ExperimentConfig

experiment_config: ExperimentConfig = experiments.dudas
experiment_config.summary()
# Out:
# ExperimentConfig(
#     name='dudas',
#     base_model=QuantumModelConfig(
#         name='Quantum Model',
#         id={},
#         loss=CrossEntropy(),
#         metric=Accuracy(),
#         batch_size=80,
#         nb_epochs=1,
#         neural_network_config=NeuralNetworkConfig(
#             name='Linear',
#             hidden_dims=[],
#             activations=[
#                 Softmax()
#             ]
#         ),
#         neural_network_optimizer_config=FirstOrderAdamConfig(
#             learning_rate=0.02,
#             beta1=0.9,
#             beta2=0.99,
#             epsilon=1e-08
#         ),
#         quantum_blackbox_config=QuantumBlackBoxConfig(
#             name='Q_Network',
#             jpc_config=JPCConfig(
#                 DIM_A=10,
#                 DIM_B=10,
#                 OMEGA_A=10000.0,
#                 OMEGA_B=9000.0,
#                 KAPPA_A=17,
#                 KAPPA_B=21,
#                 K_AA=0.1,
#                 K_BB=0.1,
# ...

# %%
experiment: Experiment = experiment_config.instantiate()
experiment.train_models(nb_print=-1)
# Out:
# Training Models
#     Training {} Model
# |██████████| 100.0% ◆ elapsed 07m22s ◆ remaining 0.00ms
#             batch n°1 out of 30, loss : 0.7351884222776821 q_params : QuantumParameters(g_conv=np.float64(700.9999946011659), epsilon_a=np.float64(64.00001866330469), epsilon_b=np.float64(65.9999945074273), delta_a=np.float64(10.999974687852339), delta_b=np.float64(11.000038643180636))
# |██████████| 100.0% ◆ elapsed 06m18s ◆ remaining 0.00ms
#             batch n°2 out of 30, loss : 0.751334617307129 q_params : QuantumParameters(g_conv=np.float64(700.7570946359322), epsilon_a=np.float64(64.27851875072848), epsilon_b=np.float64(66.59056023851718), delta_a=np.float64(10.580047341827633), delta_b=np.float64(10.000704641380832))
# |██████████| 100.0% ◆ elapsed 05m13s ◆ remaining 0.00ms
# ...

# %%
experiment.plot_losses(title="",
                       plot_dimension=0,
                       smooth_fraction=0.05)
