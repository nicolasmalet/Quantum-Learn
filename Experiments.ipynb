# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import sys
import os

PROJECT_PATH = '/content/drive/MyDrive/PycharmProjects/Quantum-Learn'
sys.path.append(PROJECT_PATH)

os.chdir(PROJECT_PATH)

# %%
# !pip install -r requirements.txt
# !pip install --upgrade --force-reinstall "jax[cuda12_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !pip install --upgrade jax-cuda12-plugin jax-cuda12-pjrt

# !sudo apt-get update
# !sudo apt-get install -y texlive-latex-extra texlive-fonts-recommended texlive-fonts-extra dvipng cm-super

# %%
from lab.sinus_vs_square_hard import experiments
from zeroth.experiment import Experiment, ExperimentConfig

experiment_config = experiments.dudas
experiment_config
# Out:
# ExperimentConfig(name='dudas', title='Training Loss Dudas', base_model=QuantumModelConfig(name='Quantum Model', id={}, loss=CrossEntropy(), metric=Accuracy(), batch_size=80, nb_epochs=1, neural_network_config=NeuralNetworkConfig(name='Linear', layers_config=[LayerConfig(input_dim=140, output_dim=2, activation=Softmax())]), neural_network_optimizer_config=FirstOrderAdamConfig(learning_rate=0.02, beta1=0.9, beta2=0.99, epsilon=1e-08), quantum_network_config=QuantumBlackBoxConfig(name='Q_Network', quantum_constants=QuantumConstants(DIM_A=15, DIM_B=15, OMEGA_A=10000.0, OMEGA_B=9000.0, KAPPA_A=17, KAPPA_B=21, K_AA=0.1, K_BB=0.1, K_AB=0.05, EPSILON_A=130, EPSILON_B=130, DRIVE_DURATION=0.04), quantum_parameters=QuantumParametersConfig(g_conv_real=700, g_conv_imag=0, g_sq_real=10, g_sq_imag=0, delta_a=0, delta_b=0), simulation_constants=SimulationConstants(MEASURE_RESOLUTION=10, SIMULATION_RESOLUTION=10)), quantum_gradient_estimator=GlobalFiniteDifferenceConfig(dA=0.01), quantum_optimizer_config=ZerothOrderAdamConfig(learning_rate=1, beta1=0.9, beta2=0.99, epsilon=1e-08), build_f=<function build_f_quadratures_poly at 0x00000189403AEFC0>), variations=[], data_creator=DataCreatorSinusHard(), plot_dimension=0, smooth_fraction=0.05)

# %%
experiment = experiment_config.instantiate()
experiment

# %%
experiment.launch(do_train=True, nb_print_train=10, do_test=True, do_plot_train=True, do_save=True)
