# %%
from lab.config.models import reservoir_model_config

reservoir_model_config.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from lab.config.models import reservoir_model_config
#       3 reservoir_model_config.summary()
#
# File G:\Mon Drive\PycharmProjects\Quantum-Learn\lab\config\models.py:1
# ----> 1 from zeroth.losses import MSE
#       2 from zeroth.losses.binary_cross_entropy import BinaryCrossEntropy
#       3 from zeroth.utils.metrics import Accuracy
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\zeroth\losses\__init__.py:1
# ----> 1 from .cross_entropy import CrossEntropy
#       2 from .mse import MSE
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\zeroth\losses\cross_entropy.py:3
#       1 import numpy as np
# ----> 3 from ..abstract.loss import Loss
#       4 from ..first_order.layer import Layer
#       5 from ..types import Array
#
# ...

# %%
from lab.sinus_vs_square_hard.data import DataCreatorSinusHard

data_creator = DataCreatorSinusHard(nb_periods_train=150, nb_periods_test=50)
data = data_creator()

# %%
reservoir_model = reservoir_model_config.instantiate(data=data)
reservoir_model.train(nb_print=-1)

# %%
Y_pred, Y_true = reservoir_model.test()

Y_pred, Y_true

# %%
X_test, Y_true = reservoir_model.data.X_test, reservoir_model.data.Y_test
F_pred = reservoir_model.quantum_blackbox(X_test)
Y_pred = reservoir_model.neural_network.forward(F_pred)

# %%
import numpy as np

f"accuracy : {np.mean((Y_pred >= 0.5) == Y_true)}, loss : {reservoir_model.loss.compute_loss(Y_pred, Y_true)}"

# %%
import matplotlib.pyplot as plt

X = range(len(Y_pred))
plt.scatter(X, Y_pred, label="QRC quadratures", color="g")
plt.plot(X, Y_true, label="Target", color="r")
plt.legend()
plt.show()
