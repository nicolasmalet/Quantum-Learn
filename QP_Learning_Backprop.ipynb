# %%
from lab.sinus_vs_square_hard.experiments import builf_f_experiment

builf_f_experiment.summary()
# Out:
# ExperimentConfig(
#     name='test_experiment',
#     base_model=QuantumModelConfig(
#         name='Quantum Model',
#         id={},
#         loss=BinaryCrossEntropy(),
#         metric=Accuracy(),
#         batch_size=80,
#         nb_epochs=1,
#         neural_network_config=NeuralNetworkConfig(
#             name='Linear',
#             hidden_dims=[],
#             activations=[
#                 Sigmoid()
#             ]
#         ),
#         neural_network_optimizer_config=FirstOrderAdamConfig(
#             learning_rate=0.02,
#             beta1=0.9,
#             beta2=0.99,
#             epsilon=1e-08
#         ),
#         quantum_blackbox_config=QuantumBlackBoxConfig(
#             name='Q_Network',
#             jpc_config=JPCConfig(
#                 DIM_A=10,
#                 DIM_B=10,
#                 OMEGA_A=10000.0,
#                 OMEGA_B=9000.0,
#                 KAPPA_A=17,
#                 KAPPA_B=21,
#                 K_AA=0.1,
# ...

# %%
experiment = builf_f_experiment.instantiate()
experiment.train_models(nb_print=-1)
# Out:
# Training Models
#     Training {'F': BuildFQuadraturesConfig()} Model
# |██████████| 100.0% ◆ elapsed 06m27s ◆ remaining 0.00ms
#             batch n°1 out of 30, loss : 0.7632557099973184 q_params : QuantumParameters(g_conv=np.float64(900.0199996505943), g_sq=np.float64(179.98000054252998), epsilon_a=np.float64(170.01999965059431), epsilon_b=np.float64(169.98000054252998), delta_a=np.float64(-0.019999457470007816), delta_b=np.float64(-0.01999965059431718))
# |██████████| 100.0% ◆ elapsed 06m07s ◆ remaining 0.00ms
#             batch n°2 out of 30, loss : 0.6229511776106559 q_params : QuantumParameters(g_conv=np.float64(900.0310001760819), g_sq=np.float64(179.9731878546828), epsilon_a=np.float64(170.03100017608185), epsilon_b=np.float64(169.96347002299183), delta_a=np.float64(-0.038051065156857945), delta_b=np.float64(-0.02920716079521477))
# |██████████| 100.0% ◆ elapsed 05m15s ◆ remaining 0.00ms
# ...
