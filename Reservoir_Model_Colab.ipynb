# %%
from google.colab import drive

drive.mount('/content/drive')

import sys
import os

PROJECT_PATH = '/content/drive/MyDrive/PycharmProjects/Quantum-Learn'
sys.path.append(PROJECT_PATH)

os.chdir(PROJECT_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r requirements.txt
# !pip install --upgrade --force-reinstall "jax[cuda12_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !pip install --upgrade jax-cuda12-plugin jax-cuda12-pjrt

# !sudo apt-get update
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.8/159.8 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 73.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 MB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 60.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 995.9/995.9 kB 65.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 99.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 9.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.7.2
# ...

# %%
from lab.config.models import reservoir_model_config

reservoir_model_config.summary()
# Out:
# ReservoirModelConfig(
#     name='Quantum Model',
#     id={},
#     loss=MSE(),
#     metric=Accuracy(),
#     batch_size=80,
#     nb_epochs=1,
#     quantum_blackbox_config=QuantumBlackBoxConfig(
#         name='Q_Network',
#         jpc_config=JPCConfig(
#             DIM_A=10,
#             DIM_B=10,
#             OMEGA_A=10000.0,
#             OMEGA_B=9000.0,
#             KAPPA_A=17,
#             KAPPA_B=21,
#             K_AA=0.1,
#             K_BB=0.1,
#             K_AB=0.05,
#             DRIVE_DURATION=0.04,
#             MEASURE_RESOLUTION=10,
#             SIMULATION_RESOLUTION=10
#         ),
#         encoding=Encoding(
#             encoding_parameters=('g_sq',),
#             encoding_function=Affine()
#         ),
#         quantum_parameters=QuantumParameters(
#             g_conv=900,
#             g_sq=180,
#             epsilon_a=170,
#             epsilon_b=170,
#             delta_a=0,
#             delta_b=0
#         ),
# ...

# %%
from lab.sinus_vs_square_hard.data import DataCreatorSinusHard

data_creator = DataCreatorSinusHard(nb_periods_train=300, nb_periods_test=50)
data = data_creator()

# %%
reservoir_model = reservoir_model_config.instantiate(data=data)
reservoir_model.train(nb_print=-1)
# Out:
#     Training {} Model
# |██████████| 100.0% ◆ elapsed 09m06s ◆ remaining 0.00ms
# Perfect W, terrible params
# |██████████| 100.0% ◆ elapsed 01m22s ◆ remaining 0.00ms
# loss : 2.022091735034501
# Perfect params terrible W
# |██████████| 100.0% ◆ elapsed 01m22s ◆ remaining 0.00ms
# loss : 2.0213105152075728
#             batch n°1 out of 30, loss : 0.49851936116996126 q_params : QuantumParameters(g_conv=np.float64(900.0049999999227), g_sq=np.float64(179.9950000000773), epsilon_a=np.float64(170.0049999999227), epsilon_b=np.float64(169.9950000000773), delta_a=np.float64(0.004999999922681701), delta_b=np.float64(0.004999999922681701))
# |██████████| 100.0% ◆ elapsed 09m02s ◆ remaining 0.00ms
# Perfect W, terrible params
# |██████████| 100.0% ◆ elapsed 01m21s ◆ remaining 0.00ms
# loss : 1.8648485486975543
# Perfect params terrible W
# |██████████| 100.0% ◆ elapsed 01m21s ◆ remaining 0.00ms
# loss : 1.8223697200487783
# ...
